# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\dasb4\Downloads\ai_financial_market_daily_realistic_synthetic.csv")

# %%
df
# Out:
#              Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0      2015-01-01  OpenAI                 5.92               0.63
# 1      2015-01-02  OpenAI                 5.41               1.81
# 2      2015-01-03  OpenAI                 4.50               0.61
# 3      2015-01-04  OpenAI                 5.45               0.95
# 4      2015-01-05  OpenAI                 3.40               1.48
# ...           ...     ...                  ...                ...
# 10954  2024-12-27    Meta               100.19             103.54
# 10955  2024-12-28    Meta                99.12             102.37
# 10956  2024-12-29    Meta                98.95             103.11
# 10957  2024-12-30    Meta               100.74             103.21
# 10958  2024-12-31    Meta               100.08             103.41
#
#        AI_Revenue_Growth_% Event  Stock_Impact_%
# 0                   -36.82   NaN           -0.36
# 1                    80.59   NaN            0.41
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  object
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: float64(4), object(3)
# memory usage: 599.4+ KB

# %%
# Convert data type of date column into Datetime format 

df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10959 entries, 0 to 10958
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 10959 non-null  datetime64[ns]
#  1   Company              10959 non-null  object
#  2   R&D_Spending_USD_Mn  10959 non-null  float64
#  3   AI_Revenue_USD_Mn    10959 non-null  float64
#  4   AI_Revenue_Growth_%  10959 non-null  float64
#  5   Event                233 non-null    object
#  6   Stock_Impact_%       10959 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 599.4+ KB

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%
# 0               -36.82   NaN           -0.36
# 1                80.59   NaN            0.41
# 2               -38.88   NaN            0.23
# 3                -5.34   NaN            0.93
# 4                48.45   NaN           -0.09

# %%
# Show the Companies Name

df['Company'].unique()
# Out:
# array(['OpenAI', 'Google', 'Meta'], dtype=object)

# %%
#Create a new column for 'year' only 

df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %% [markdown]
# **How Much Amount The companies Spent on R & D ?**

# %%
print("Company's spending for R & D in $Bn")
rd = df.groupby('Company')['R&D_Spending_USD_Mn'].sum()/1000
rd
# Out:
# Company's spending for R & D in $Bn
# Company
# Google    423.34114
# Meta      264.53307
# OpenAI     26.48277
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
plt.bar(rd.index, rd.values, color = ['green','orange','purple'])
plt.title("R&D Spending by the companies ")
plt.xlabel("Company",fontweight = 'bold',color = 'red')
plt.ylabel("Amount in USD_$Bn",fontweight = 'bold',color = 'red')
plt.grid('-',alpha = 0.1)
plt.show()

# %% [markdown]
# **Revenue Earned by the Companies**

# %%
df.head(1)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015

# %%
# Print("Company's AI  Revenue in USD $Bn")
Rev = df.groupby('Company')['AI_Revenue_USD_Mn'].sum()/100
Rev
# Out:
# Company
# Google    2844.9838
# Meta      1896.2182
# OpenAI      94.6289
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
 # Draw a Bar Plot to show the Revenues of the companies 

plt.bar(Rev.index,Rev.values, color = ['green','orange','purple'],width = 0.5)
plt.title("Company's AI Revenue in USD $Bn")
plt.xlabel("Company",fontweight = 'bold',color = 'red')
plt.ylabel("Amount in USD_$Bn",fontweight = 'bold',color = 'red')
plt.grid('-',alpha = 0.1)
plt.show()

# %%
# Bar plots to show expenditure & revenue of the companies

plt.figure(figsize = (10,4))

plt.subplot(1,2,1)

plt.bar(rd.index, rd.values, color = ['green','orange','purple'])
plt.title("R&D Spending by the companies ")
plt.xlabel("Company",fontweight = 'bold',color = 'red')
plt.ylabel("Amount in USD_$Bn",fontweight = 'bold',color = 'red')
plt.grid('-',alpha = 0.1)

plt.subplot(1,2,2)

plt.bar(Rev.index,Rev.values, color = ['green','orange','purple'],width = 0.5)
plt.title("Company's AI Revenue in USD $Bn")
plt.xlabel("Company",fontweight = 'bold',color = 'red')
plt.ylabel("Amount in USD_$Bn",fontweight = 'bold',color = 'red')
plt.grid('-',alpha = 0.1)
plt.show()

# %% [markdown]
# **Datewise Impact on the Stock**

# %%
df.head(1)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015

# %%
plt.figure(figsize = (10,5))

plt.plot(df['Date'],df['Stock_Impact_%'], color = 'green')

plt.title("Change is Stock value")
plt.xlabel("Date(Year)",fontweight = 'bold',color = 'red')
plt.ylabel("Stock_Impact_%",fontweight = 'bold',color = 'red')
plt.grid('-',alpha = 0.5)
plt.show()

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
data_openAI = df [df['Company'] == 'OpenAI']

# %%
data_openAI.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
data_Google = df [df['Company'] == 'Google']

# %%
data_Google.head()
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3653 2015-01-01  Google                79.89              30.19
# 3654 2015-01-02  Google                78.99              30.44
# 3655 2015-01-03  Google                79.20              30.46
# 3656 2015-01-04  Google                79.59              30.55
# 3657 2015-01-05  Google                81.50              30.59
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 3653                 0.64   NaN           -0.02  2015
# 3654                 1.47   NaN           -0.98  2015
# 3655                 1.53   NaN            0.78  2015
# 3656                 1.82   NaN           -0.41  2015
# 3657                 1.97   NaN           -0.78  2015

# %%
data_Meta = df [df['Company'] == 'Meta']

# %%
data_Meta.head()
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 7306 2015-01-01    Meta                50.39              18.95
# 7307 2015-01-02    Meta                49.80              19.77
# 7308 2015-01-03    Meta                49.09              19.96
# 7309 2015-01-04    Meta                50.66              20.48
# 7310 2015-01-05    Meta                51.36              19.84
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 7306                -5.23   NaN           -0.42  2015
# 7307                -1.16   NaN            0.63  2015
# 7308                -0.21   NaN            0.73  2015
# 7309                 2.38   NaN           -0.26  2015
# 7310                -0.80   NaN           -0.37  2015

# %%
plt.figure(figsize = (10,5))

plt.plot(data_openAI['Date'], data_openAI['Stock_Impact_%'], color = 'purple')

plt.title("Change in Stock Value of OpenAI")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %%
plt.figure(figsize = (10,5))

plt.plot(data_Google['Date'], data_Google['Stock_Impact_%'], color = 'g')

plt.title("Change in Stock Value of Google")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %%
plt.figure(figsize = (10,5))

plt.plot(data_Meta['Date'], data_Meta['Stock_Impact_%'], color = 'orange' )

plt.title("Change in Stock Value of Meta")
plt.xlabel("Date")
plt.ylabel("Stock_Impact_%")
plt.show()

# %% [markdown]
# **Events when Maximum Stock Impact was observed**

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
# Open AI's Events when Maximum Stock Impact was Observed

data_openAI
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0    2015-01-01  OpenAI                 5.92               0.63
# 1    2015-01-02  OpenAI                 5.41               1.81
# 2    2015-01-03  OpenAI                 4.50               0.61
# 3    2015-01-04  OpenAI                 5.45               0.95
# 4    2015-01-05  OpenAI                 3.40               1.48
# ...         ...     ...                  ...                ...
# 3648 2024-12-27  OpenAI                10.06               4.71
# 3649 2024-12-28  OpenAI                 9.67               5.32
# 3650 2024-12-29  OpenAI                 9.17               5.46
# 3651 2024-12-30  OpenAI                10.36               6.31
# 3652 2024-12-31  OpenAI                10.24               4.92
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0                  -36.82   NaN           -0.36  2015
# 1                   80.59   NaN            0.41  2015
# ...

# %%
data_openAI.sort_values( by = 'Stock_Impact_%',ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3408 2024-05-01  OpenAI                10.91               5.34
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2890 2022-11-30  OpenAI                10.60               3.18
# 2652 2022-04-06  OpenAI                 9.24               3.48
# 1988 2020-06-11  OpenAI                 5.90               2.62
# ...         ...     ...                  ...                ...
# 3590 2024-10-30  OpenAI                11.05               5.27
# 1212 2018-04-27  OpenAI                 5.38               1.76
# 1303 2018-07-27  OpenAI                 7.44               0.97
# 2480 2021-10-16  OpenAI                 8.39               2.78
# 3350 2024-03-04  OpenAI                10.82               4.77
#
#       AI_Revenue_Growth_%                        Event  Stock_Impact_%  Year
# 3408               434.27    GPT-5 release (predicted)           18.50  2024
# ...

# %%
data_Google
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3653 2015-01-01  Google                79.89              30.19
# 3654 2015-01-02  Google                78.99              30.44
# 3655 2015-01-03  Google                79.20              30.46
# 3656 2015-01-04  Google                79.59              30.55
# 3657 2015-01-05  Google                81.50              30.59
# ...         ...     ...                  ...                ...
# 7301 2024-12-27  Google               162.16             155.36
# 7302 2024-12-28  Google               159.69             154.47
# 7303 2024-12-29  Google               161.69             154.59
# 7304 2024-12-30  Google               158.48             155.05
# 7305 2024-12-31  Google               159.48             154.77
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 3653                 0.64   NaN           -0.02  2015
# 3654                 1.47   NaN           -0.98  2015
# ...

# %%
data_Google.sort_values( by = 'Stock_Impact_%',ascending = False)
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 4092 2016-03-15  Google                84.56              36.22
# 6914 2023-12-06  Google               146.59             129.17
# 6654 2023-03-21  Google               149.34             129.76
# 3883 2015-08-19  Google                79.27              30.89
# 6388 2022-06-28  Google               137.71             107.96
# ...         ...     ...                  ...                ...
# 4122 2016-04-14  Google                87.19              36.08
# 4412 2017-01-29  Google                92.21              43.25
# 6303 2022-04-04  Google               138.00             106.81
# 3803 2015-05-31  Google                81.14              29.30
# 5479 2020-01-01  Google               117.24              74.82
#
#       AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 4092                20.73          AlphaGo beats Lee Sedol            6.20
# ...

# %%
data_Meta.sort_values( by = 'Stock_Impact_%',ascending = False)
# Out:
#             Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 10731 2024-05-18    Meta               103.64             103.05
# 10426 2023-07-18    Meta                92.44              85.67
# 10282 2023-02-24    Meta                93.71              86.98
# 9156  2020-01-25    Meta                72.73              49.10
# 7526  2015-08-09    Meta                48.97              19.95
# ...          ...     ...                  ...                ...
# 10604 2024-01-12    Meta                99.37             104.28
# 7875  2016-07-23    Meta                53.76              23.97
# 8026  2016-12-21    Meta                53.18              23.42
# 9964  2022-04-12    Meta                84.90              71.99
# 10785 2024-07-11    Meta               100.78             102.92
#
#        AI_Revenue_Growth_%                            Event  Stock_Impact_%  \
# 10731               415.23      LLaMA 3 release (predicted)            7.40
# ...

# %% [markdown]
# **Ai Revenue Growth of the Companies**

# %%
df.head(1)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015

# %%
sns.scatterplot(x = 'Date',y = 'AI_Revenue_Growth_%',data = df,hue = 'Company')
plt.show()

# %%
df.sort_values( by = ['AI_Revenue_Growth_%'])
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 189  2015-07-09  OpenAI                 5.66              -0.55
# 205  2015-07-25  OpenAI                 5.23              -0.42
# 649  2016-10-11  OpenAI                 5.37              -0.35
# 548  2016-07-02  OpenAI                 5.19              -0.29
# 98   2015-04-09  OpenAI                 4.80              -0.25
# ...         ...     ...                  ...                ...
# 3508 2024-08-09  OpenAI                 9.92               6.33
# 3645 2024-12-24  OpenAI                 8.79               6.46
# 3627 2024-12-06  OpenAI                 8.51               6.49
# 3612 2024-11-21  OpenAI                10.16               6.59
# 3423 2024-05-16  OpenAI                 8.47               6.65
#
#       AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 189               -155.43   NaN            0.70  2015
# 205               -141.61   NaN           -0.62  2015
# ...

# %% [markdown]
# **OpenAI's AI Revenue Growth Year-by-Year**

# %%
plt.plot(data_openAI['Date'],data_openAI ['AI_Revenue_Growth_%'],color = 'purple')

plt.show()

# %% [markdown]
# **Google's Ai Revenue Growth year-by-year**

# %%
plt.plot(data_Google['Date'],data_Google ['AI_Revenue_Growth_%'],color = 'green')

plt.show()

# %% [markdown]
# **Meta's Ai Revenue Growth year-by-year**

# %%
plt.plot(data_Meta['Date'],data_Meta ['AI_Revenue_Growth_%'],color = ('orange'))

plt.show()

# %% [markdown]
# **Correlation between the columns**

# %%
sns.heatmap(df.corr(numeric_only = True))

plt.show()

# %% [markdown]
# **Expenditure vs Revenue year-by-year**

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
spend = df.groupby('Year')['R&D_Spending_USD_Mn'].sum()
spend
# Out:
# Year
# 2015    49304.23
# 2016    53349.94
# 2017    57475.12
# 2018    62002.16
# 2019    67071.51
# 2020    72602.53
# 2021    78207.32
# 2022    84390.17
# 2023    91193.92
# 2024    98760.08
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Showing the Amount spent on R & D

plt.plot(spend.index,spend.values,color ='r')
plt.title("Combined R&D Spending Year-by-Year")
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.show()

# %%
Revenue = df.groupby('Year')['AI_Revenue_USD_Mn'].sum()
Revenue
# Out:
# Year
# 2015    18623.21
# 2016    22361.20
# 2017    26776.80
# 2018    32164.44
# 2019    38580.32
# 2020    46456.19
# 2021    55591.14
# 2022    66674.24
# 2023    80041.64
# 2024    96313.91
# Name: AI_Revenue_USD_Mn, dtype: float64

# %%
# Showing the Revenue Earned

plt.plot(Revenue.index, Revenue.values,color = 'orange')
plt.title("Combined Revenue Earned Year-by-Year")
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.show()

# %%
plt.plot(spend.index,spend.values,color ='r')
plt.plot(Revenue.index, Revenue.values,color = 'g')
plt.title("Combined Expenditure vs Revenue Year-by-Year",fontsize = 10)
plt.xlabel("Year")
plt.ylabel("Amount in USD_$Mn")
plt.legend(['Expenditure','Revenue'])
plt.grid()
plt.show()

# %%
# Pariplot to show the relations between the columns

sns.pairplot(df);
plt.savefig("seaborn_chart.png", dpi=80, bbox_inches='tight')

# %% [markdown]
# **Event Impact Analysis**

# %%
df.head()
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
# 2 2015-01-03  OpenAI                 4.50               0.61
# 3 2015-01-04  OpenAI                 5.45               0.95
# 4 2015-01-05  OpenAI                 3.40               1.48
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015
# 2               -38.88   NaN            0.23  2015
# 3                -5.34   NaN            0.93  2015
# 4                48.45   NaN           -0.09  2015

# %%
# Showing the various Events

df.Event.value_counts()
# Out:
# Event
# AI speech recognition release      37
# AI Ads Optimization upgrade        32
# AI partnership deal                32
# AI-powered search update           32
# AI Video Recommendation upgrade    29
# AI ethics policy update            27
# Cloud AI launch                    27
# GPT-1 release                       1
# GPT-2 release                       1
# GPT-3 release                       1
# Codex release                       1
# DALL·E 2 release                    1
# ChatGPT (GPT-3.5) launch            1
# GPT-4 release                       1
# GPT-5 release (predicted)           1
# TensorFlow open-source release      1
# AlphaGo beats Lee Sedol             1
# BERT for Search launch              1
# MUM Search Model launch             1
# Bard chatbot launch                 1
# Gemini AI release                   1
# LLaMA 1 release                     1
# LLaMA 2 release                     1
# LLaMA 3 release (predicted)         1
# Name: count, dtype: int64

# %%
# Checking for a particular event

df[df.Event == 'TensorFlow open-source release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3965 2015-11-09  Google                79.62              29.84
#
#       AI_Revenue_Growth_%                           Event  Stock_Impact_%  \
# 3965                -0.53  TensorFlow open-source release             4.5
#
#       Year
# 3965  2015

# %%
tf = df.loc[3955:3975]
tf
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 3955 2015-10-30  Google                80.33              29.87
# 3956 2015-10-31  Google                79.53              30.30
# 3957 2015-11-01  Google                80.37              29.86
# 3958 2015-11-02  Google                77.89              29.97
# 3959 2015-11-03  Google                81.00              29.43
# 3960 2015-11-04  Google                80.70              29.71
# 3961 2015-11-05  Google                78.31              30.25
# 3962 2015-11-06  Google                79.08              29.84
# 3963 2015-11-07  Google                79.65              30.34
# 3964 2015-11-08  Google                79.63              29.74
# 3965 2015-11-09  Google                79.62              29.84
# 3966 2015-11-10  Google                81.65              29.44
# 3967 2015-11-11  Google                78.67              30.02
# 3968 2015-11-12  Google                81.43              29.56
# ...

# %%
# Showing the Impact with a line chart

plt.figure(figsize = (10,4))

plt.plot(tf['Date'], tf['Stock_Impact_%'], color = 'c')
plt.title("Comparison before and after the release of TenserFow Open-Source",color = 'b')
plt.xlabel("Date",color = 'b')
plt.ylabel("Change in Stock %",color = 'b')
plt.grid()
plt.show()

# %%
# Checking for a particular event

df[df.Event == 'GPT-4 release']
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2994 2023-03-14  OpenAI                 7.78               4.05
#
#       AI_Revenue_Growth_%          Event  Stock_Impact_%  Year
# 2994               304.57  GPT-4 release            15.2  2023

# %%
gpt4 = df.loc[ 2984:3004]
gpt4
# Out:
#            Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 2984 2023-03-04  OpenAI                10.59               4.26
# 2985 2023-03-05  OpenAI                 8.24               3.58
# 2986 2023-03-06  OpenAI                 9.32               4.21
# 2987 2023-03-07  OpenAI                 8.52               4.13
# 2988 2023-03-08  OpenAI                 8.90               3.63
# 2989 2023-03-09  OpenAI                 8.44               4.64
# 2990 2023-03-10  OpenAI                 9.55               4.83
# 2991 2023-03-11  OpenAI                 8.34               3.95
# 2992 2023-03-12  OpenAI                 8.71               3.57
# 2993 2023-03-13  OpenAI                10.61               5.19
# 2994 2023-03-14  OpenAI                 7.78               4.05
# 2995 2023-03-15  OpenAI                12.31               4.44
# 2996 2023-03-16  OpenAI                10.60               4.64
# 2997 2023-03-17  OpenAI                10.77               4.78
# ...

# %%
plt.figure(figsize = (10,4))

plt.plot(gpt4['Date'], gpt4['Stock_Impact_%'], color = 'm')
plt.title("Comparison before and after the release of GPT4",color = 'b')
plt.xlabel("Date",color = 'b')
plt.ylabel("Change in Stock %",color = 'b')
plt.grid()
plt.show()

# %%
df.head(2)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015

# %%
# Daily Average impact on the stocks of the companies

df.groupby('Company')['Stock_Impact_%'].mean()*100
# Out:
# Company
# Google    2.620860
# Meta      0.976184
# OpenAI    4.070901
# Name: Stock_Impact_%, dtype: float64

# %%
# Daily Average expenditure on R&D By the companies

df.groupby('Company')['R&D_Spending_USD_Mn'].mean()
# Out:
# Company
# Google    115.888623
# Meta       72.415294
# OpenAI      7.249595
# Name: R&D_Spending_USD_Mn, dtype: float64

# %%
# Maximum impact % On a company's stocks

df.groupby('Company')['Stock_Impact_%'].max()
# Out:
# Company
# Google     6.2
# Meta       7.4
# OpenAI    18.5
# Name: Stock_Impact_%, dtype: float64

# %% [markdown]
# **Change in the index with respect to Year & Company**

# %%
df.head(2)
# Out:
#         Date Company  R&D_Spending_USD_Mn  AI_Revenue_USD_Mn  \
# 0 2015-01-01  OpenAI                 5.92               0.63
# 1 2015-01-02  OpenAI                 5.41               1.81
#
#    AI_Revenue_Growth_% Event  Stock_Impact_%  Year
# 0               -36.82   NaN           -0.36  2015
# 1                80.59   NaN            0.41  2015

# %%
# Highest change in the index

stocks = df.groupby(['Year','Company'])['Stock_Impact_%'].max()

stocks
# Out:
# Year  Company
# 2015  Google      4.96
#       Meta        4.80
#       OpenAI      3.92
# 2016  Google      6.20
#       Meta        2.14
#       OpenAI      4.66
# 2017  Google      4.42
#       Meta        4.21
#       OpenAI      4.63
# 2018  Google      1.97
#       Meta        4.54
#       OpenAI      4.94
# 2019  Google      3.20
#       Meta        1.86
#       OpenAI      4.20
# 2020  Google      4.18
#       Meta        4.86
#       OpenAI      8.50
# 2021  Google      4.10
#       Meta        4.80
#       OpenAI      7.20
# 2022  Google      4.88
#       Meta        3.98
#       OpenAI     12.00
# 2023  Google      5.80
#       Meta        6.80
#       OpenAI     15.20
# 2024  Google      2.89
#       Meta        7.40
#       OpenAI     18.50
# Name: Stock_Impact_%, dtype: float64

# %%
stocks.plot(kind = 'barh',color = ['b','g','orange'])

plt.title("Change in Stocks",color = 'b')
plt.show()

# %% [markdown]
# **Dataset related to financial market of AI companies.**
# This dataset provides a synthetic, daily record of financial market activities related to companies involved in Artificial Intelligence (AI).
# There are key financial metrics and events that could influence a company's stock performance like launch of Llama by Meta, launch of GPT by OpenAI, launch of Gemini by Google etc.
# Here, we have the data about how much amount the companies are spending on R & D of their AI's Products & Services, and how much revenue these companies are generating.
# The data is from January 1, 2015, to December 31, 2024, and includes information for various companies : OpenAI, Google and Meta.
# This data is available as a CSV file. We are going to analyze this data set using the Pandas DataFrame.
# This analyse will be helpful for those working in Finance or Share Market domain.
#
# From this dataset, we extract various insights using Python in our Project.
# 1) How much amount the companies spent on R & D ?
# 2) Revenue Earned by the companies
# 3) Date-wise Impact on the Stock
# 4) Events when Maximum Stock Impact was observed
# 5) AI Revenue Growth of the companies
# 6) Correlation between the columns
# 7) Expenditure vs Revenue year-by-year
# 8) Event Impact Analysis
# 9) Change in the index wrt Year & Company
